# %%
#Amielle James A. Nicolas
#DS1A
#1.)

import matplotlib.pyplot as plt

months = ['Jan', 'Feb', 'Mar', 'Apr', 'May']
sales = [120, 150, 180, 200, 250]

plt.plot(months, sales)
plt.title("Monthly Sales Trend")
plt.xlabel("Months")
plt.ylabel("Sales")
plt.show()

# %%
#2.)

classes = ['Class A', 'Class B', 'Class C']
students = [25, 30, 22]

plt.bar(classes, students)
plt.title("Number of Students per Class")
plt.xlabel("Classes")
plt.ylabel("Students")
plt.show()

# %%
#3.)

hours = [1, 2, 3, 4, 5]
scores = [40, 50, 60, 70, 85]

plt.scatter(hours, scores)
plt.title("Study Hours vs. Test Scores")
plt.xlabel("Hours")
plt.ylabel("Scores")
plt.show()

# %%
hours = [1, 2, 3, 4, 5]
scores = [40, 50, 60, 70, 85]

plt.scatter(hours, scores, color='red', marker='o', label='improved_plot.png')
plt.legend()
plt.grid(True)
