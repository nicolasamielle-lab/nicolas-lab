# %% [markdown]
# <a href="https://colab.research.google.com/github/nicolasamielle-lab/nicolas-lab/blob/main/NICOLAS_CHAP_7_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Amielle James A. Nicolas
#DS1A
#1.)

def calculate_area(length, width):
    """
    This function finds the area of a
    rectangle using its length and width.
    It takes two numbers as input and
    returns the result of multiplying them.
    """
    return length * width

#Ask the user for length of the rectangle.
length = int(input("Enter the length: "))
#Ask the user for width of the rectangle.
width = int(input("Enter the width: "))
#Use function to calculate the area.
area = calculate_area(length, width)
#Display the result
print("The area of the rectangle is", area)
# Out:
# Enter the length: 5
# Enter the width: 3
# The area of the rectangle is 15
