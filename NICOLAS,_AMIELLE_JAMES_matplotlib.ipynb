# %% [markdown]
# <a href="https://colab.research.google.com/github/nicolasamielle-lab/nicolas-lab/blob/main/NICOLAS%2C_AMIELLE_JAMES_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {'Name': ['Amielle', 'Jeryl', 'Ralph', 'Bea', 'Era'],
        'Math': [95, 94, 93, 90, 91],
        'Science': [94, 93, 93, 95, 92],
        'English': [97, 95, 96, 94, 93]}

df = pd.DataFrame(data)
df['Average'] = df[['Math', 'Science', 'English']].mean(axis=1)

print("Student Scores: \n", df)

plt.bar(df['Name'], df['Average'], color='skyblue')
plt.title("Average Scores of Students")
plt.xlabel("Students")
plt.ylabel("Average Scores")
plt.ylim(0, 100)

plt.show()
# Out:
# Student Scores:
#        Name  Math  Science  English    Average
# 0  Amielle    95       94       97  95.333333
# 1    Jeryl    94       93       95  94.000000
# 2    Ralph    93       93       96  94.000000
# 3      Bea    90       95       94  93.000000
# 4      Era    91       92       93  92.000000
